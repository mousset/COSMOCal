# %% [markdown]
# # Quick look at the data
#
# edited by Louise 23/01/2026

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
save_path = "..\\VNA_data\\"
mag = np.load(save_path + "mag.npy") # [nstep, nS, points]
phi = np.load(save_path + "phi.npy") # [nstep, nS, points]

nstep, nS, points = mag.shape
print(mag.shape)
print(phi.shape)

# %%
print(mag)
